# %% [markdown]
# ### Batch Gradient Descent
# ![Screenshot%20from%202021-11-09%2021-58-46.png](attachment:Screenshot%20from%202021-11-09%2021-58-46.png)

# %% [markdown]
# But,What happen if we have a millions of rows .
# ![Screenshot%20from%202021-11-09%2022-02-45.png](attachment:Screenshot%20from%202021-11-09%2022-02-45.png)
