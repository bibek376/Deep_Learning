# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.pandas.set_option('display.max_columns',0)

# %%
data=pd.read_csv('CreditCard.csv',index_col=0)
data.head()
# Out:
#   card  reports       age  income  ...  dependents  months majorcards active
# 1  yes        0  37.66667  4.5200  ...           3      54          1     12
# 2  yes        0  33.25000  2.4200  ...           3      34          1     13
# 3  yes        0  33.66667  4.5000  ...           4      58          1      5
# 4  yes        0  30.50000  2.5400  ...           0      25          1      7
# 5  yes        0  32.16667  9.7867  ...           2      64          1      5
#
# [5 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# card           0
# reports        0
# age            0
# income         0
# share          0
# expenditure    0
# owner          0
# selfemp        0
# dependents     0
# months         0
# majorcards     0
# active         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['card', 'reports', 'age', 'income', 'share', 'expenditure', 'owner',
#        'selfemp', 'dependents', 'months', 'majorcards', 'active'],
#       dtype='object')

# %%
data.nunique()
# Out:
# card              2
# reports          13
# age             418
# income          431
# share          1162
# expenditure     981
# owner             2
# selfemp           2
# dependents        7
# months          193
# majorcards        2
# active           35
# dtype: int64

# %%
data['dependents'].unique()
# Out:
# array([3, 4, 0, 2, 1, 6, 5])

# %%
data[data['age']>30]
data.head()
# Out:
#   card  reports       age  income  ...  dependents  months majorcards active
# 1  yes        0  37.66667  4.5200  ...           3      54          1     12
# 2  yes        0  33.25000  2.4200  ...           3      34          1     13
# 3  yes        0  33.66667  4.5000  ...           4      58          1      5
# 4  yes        0  30.50000  2.5400  ...           0      25          1      7
# 5  yes        0  32.16667  9.7867  ...           2      64          1      5
#
# [5 rows x 12 columns]

# %%
data_scatter=data.copy()

# %%
data_scatter.shape
# Out:
# (1319, 12)

# %%
df=data[data['active']>6][['age','income','share']]
df.head()
# Out:
#          age  income     share
# 1   37.66667    4.52  0.033270
# 2   33.25000    2.42  0.005217
# 4   30.50000    2.54  0.065214
# 10  28.41667    3.20  0.019780
# 11  30.50000    3.95  0.078025

# %%
sns.distplot(data['income'] ,bins=5)
# Out:
# <AxesSubplot:xlabel='income', ylabel='Density'>

# %%
sns.pairplot(data)

# %%
corelation=df.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
data_line=data[['income','expenditure','card']]

# %%
data_line.isnull().sum()
# Out:
# income         0
# expenditure    0
# card           0
# dtype: int64

# %%
plt.figure(figsize=(12,5))
plt.title("Income And Expenditure comparision in terms of Credit Card")
sns.scatterplot(x=data_scatter['income'], y=data_scatter['expenditure'], hue=data_scatter['card'])
# Out:
# <AxesSubplot:title={'center':'Income And Expenditure comparision in terms of Credit Card'}, xlabel='income', ylabel='expenditure'>
